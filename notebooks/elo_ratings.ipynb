# %%
import pandas as pd
import numpy as np
from datafc import eloratings

# %%
france = eloratings.country_matches_data("France")
france.head(15)
# Out:
#    query_country       date team_a team_b  team_a_score  team_b_score  \
# 0         France 1904-05-01     BE     FR             3             3
# 1         France 1905-02-12     FR     CH             1             0
# 2         France 1905-05-07     BE     FR             7             0
# 3         France 1906-04-22     FR     BE             0             5
# 4         France 1906-11-01     FR     EN             0            15
# 5         France 1907-04-21     BE     FR             1             2
# 6         France 1908-03-08     CH     FR             1             2
# 7         France 1908-03-23     EN     FR            12             0
# 8         France 1908-04-12     FR     BE             1             2
# 9         France 1908-05-10     NL     FR             4             1
# 10        France 1908-10-22     DK     FR            17             1
# 11        France 1909-05-09     BE     FR             5             2
# ...

# %%
france["date"].dt.year.unique()
# Out:
# array([1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914,
#        1916, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927,
#        1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938,
#        1939, 1940, 1942, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951,
#        1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962,
#        1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973,
#        1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984,
#        1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#        2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026], dtype=int32)

# %%
france["date"].dt.year.value_counts().sort_index()
# Out:
# date
# 1904     1
# 1905     2
# 1906     2
# 1907     1
# 1908     5
#         ..
# 2022    15
# 2023    10
# 2024    16
# 2025    10
# 2026    11
# Name: count, Length: 119, dtype: int64

# %%
teams = eloratings.teams_data()

# %%
countries = pd.read_csv("../data/clean/international_matches.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 countries = pd.read_csv("../data/clean/international_matches.csv")
#
# File c:\Users\yahar\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
eloratings.country_matches_data("ES")
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 eloratings.country_matches_data("ES")
#
# File c:\Users\yahar\anaconda3\Lib\site-packages\datafc\eloratings\fetch_country_matches_data.py:34, in country_matches_data(country, rate_limit, cache)
#      32 url = f"{get_eloratings_base_url()}/{country_clean}.tsv"
#      33 with EloRatingsClient(rate_limit=rate_limit, cache=cache) as client:
# ---> 34     text = client.get(url)
#      35 return parse_country_matches(text, country_clean)
#
# File c:\Users\yahar\anaconda3\Lib\site-packages\datafc\eloratings\_client.py:92, in EloRatingsClient.get(self, url)
#      89         last_exc = ServerError(response.status_code, url)
#      90         continue
# ---> 92     raise APIError(response.status_code, url)
#      94 except (APIError, RateLimitError, ServerError):
#      95     raise
#
# ...

# %%
[f for f in dir(eloratings) if not f.startswith("_")]
# Out:
# ['country_codes_data',
#  'country_matches_data',
#  'fetch_country_codes_data',
#  'fetch_country_matches_data',
#  'fetch_teams_data',
#  'fetch_tournament_codes_data',
#  'fetch_tournament_editions_data',
#  'fetch_tournament_groups_data',
#  'fetch_world_ranking_data',
#  'get_eloratings_base_url',
#  'reset_eloratings_base_url',
#  'set_eloratings_base_url',
#  'teams_data',
#  'tournament_codes_data',
#  'tournament_editions_data',
#  'tournament_groups_data',
#  'world_ranking_data']
